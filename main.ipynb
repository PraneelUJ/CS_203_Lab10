# %% [markdown]
# ### Task1

# %%
import pandas as pd
from statsmodels.stats.proportion import proportions_ztest
import numpy as np

# %%
df=pd.read_csv("ad_click_dataset.csv")
df
# Out:
#         id full_name   age      gender device_type ad_position  \
# 0      670   User670  22.0         NaN     Desktop         Top
# 1     3044  User3044   NaN        Male     Desktop         Top
# 2     5912  User5912  41.0  Non-Binary         NaN        Side
# 3     5418  User5418  34.0        Male         NaN         NaN
# 4     9452  User9452  39.0  Non-Binary         NaN         NaN
# ...    ...       ...   ...         ...         ...         ...
# 9995  8510  User8510   NaN         NaN      Mobile         Top
# 9996  7843  User7843   NaN      Female     Desktop      Bottom
# 9997  3914  User3914   NaN        Male      Mobile        Side
# 9998  7924  User7924   NaN         NaN     Desktop         NaN
# 9999  3056  User3056  44.0        Male      Tablet         Top
#
#      browsing_history time_of_day  click
# 0            Shopping   Afternoon      1
# 1                 NaN         NaN      1
# 2           Education       Night      1
# 3       Entertainment     Evening      1
# ...

# %%
df = df.dropna(subset=['click'])
df = df.dropna(subset=['gender'])
df = df.dropna(subset=['ad_position'])

# %%
df
# Out:
#         id full_name   age      gender device_type ad_position  \
# 1     3044  User3044   NaN        Male     Desktop         Top
# 2     5912  User5912  41.0  Non-Binary         NaN        Side
# 5     5942  User5942   NaN  Non-Binary         NaN      Bottom
# 6     7808  User7808  26.0      Female     Desktop         Top
# 7     5065  User5065  40.0        Male      Mobile        Side
# ...    ...       ...   ...         ...         ...         ...
# 9986  5574  User5574  52.0      Female     Desktop      Bottom
# 9990  9540  User9540  64.0  Non-Binary         NaN        Side
# 9996  7843  User7843   NaN      Female     Desktop      Bottom
# 9997  3914  User3914   NaN        Male      Mobile        Side
# 9999  3056  User3056  44.0        Male      Tablet         Top
#
#      browsing_history time_of_day  click
# 1                 NaN         NaN      1
# 2           Education       Night      1
# 5        Social Media     Evening      1
# 6                 NaN         NaN      1
# ...

# %%
print(df['gender'].unique())
print(df['ad_position'].unique())
# Out:
# ['Male' 'Non-Binary' 'Female']
# ['Top' 'Side' 'Bottom']

# %%
df['gender'] = df['gender'].map({'Male': 0, 'Female': 1, 'Non-Binary': 2})
df['ad_position'] = df['ad_position'].map({'Top':0,'Bottom':1,'Side':2})

# %%
df
# Out:
#         id full_name   age  gender device_type  ad_position browsing_history  \
# 1     3044  User3044   NaN       0     Desktop            0              NaN
# 2     5912  User5912  41.0       2         NaN            2        Education
# 5     5942  User5942   NaN       2         NaN            1     Social Media
# 6     7808  User7808  26.0       1     Desktop            0              NaN
# 7     5065  User5065  40.0       0      Mobile            2              NaN
# ...    ...       ...   ...     ...         ...          ...              ...
# 9986  5574  User5574  52.0       1     Desktop            1         Shopping
# 9990  9540  User9540  64.0       2         NaN            2        Education
# 9996  7843  User7843   NaN       1     Desktop            1    Entertainment
# 9997  3914  User3914   NaN       0      Mobile            2              NaN
# 9999  3056  User3056  44.0       0      Tablet            0     Social Media
#
#      time_of_day  click
# ...

# %%
groupa=df[df['ad_position']==0]

groupb=df[df['ad_position']==1]

# %%
groupa
# Out:
#         id full_name   age  gender device_type  ad_position browsing_history  \
# 1     3044  User3044   NaN       0     Desktop            0              NaN
# 6     7808  User7808  26.0       1     Desktop            0              NaN
# 18    2124  User2124   NaN       0     Desktop            0              NaN
# 28    6724  User6724  37.0       1         NaN            0    Entertainment
# 31    1729  User1729  26.0       1      Mobile            0              NaN
# ...    ...       ...   ...     ...         ...          ...              ...
# 9960  9638  User9638  64.0       2     Desktop            0    Entertainment
# 9964   373   User373  34.0       1      Mobile            0              NaN
# 9981  7808  User7808  26.0       1     Desktop            0              NaN
# 9982  3574  User3574   NaN       1      Tablet            0    Entertainment
# 9999  3056  User3056  44.0       0      Tablet            0     Social Media
#
#      time_of_day  click
# ...

# %%
groupb
# Out:
#         id full_name   age  gender device_type  ad_position browsing_history  \
# 5     5942  User5942   NaN       2         NaN            1     Social Media
# 8     7993  User7993   NaN       2      Mobile            1     Social Media
# 16    8127  User8127   NaN       0      Tablet            1              NaN
# 17     188   User188  56.0       1      Tablet            1             News
# 25    4890  User4890  43.0       0      Tablet            1        Education
# ...    ...       ...   ...     ...         ...          ...              ...
# 9975  9871  User9871  41.0       0     Desktop            1              NaN
# 9979  8337  User8337   NaN       1         NaN            1    Entertainment
# 9983  4254  User4254   NaN       0     Desktop            1              NaN
# 9986  5574  User5574  52.0       1     Desktop            1         Shopping
# 9996  7843  User7843   NaN       1     Desktop            1    Entertainment
#
#      time_of_day  click
# ...

# %%
a=groupa['click'].sum()

b=groupb['click'].sum()

lena=len(groupa)
lenb=len(groupb)

counting=[a,b]
lens=[lena,lenb]

zscore,pvalue=proportions_ztest(counting,lens)

print(f"Z-Score: {zscore}")
print(f"P-Value: {pvalue}")
# Out:
# Z-Score: -2.9832500834568774
# P-Value: 0.002852048503930551

# %% [markdown]
# Yes, there is statistically significant difference in the click rates of top and bottom ad_position
#
# * As z score is -2.98 the difference between 2 groups click rates is 3 standard deviations away from the mean under null hypothesis.
# * p value is 0.00285 which is much less than 0.05, hence we reject null hypothesis which stated that there is no difference in click rates in the top and bottom ad-position
